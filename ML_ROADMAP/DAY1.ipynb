# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5,6,7])           #Normal py list-->numpy array

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
arr.dtype                                 #attributes or stored info (dtype,shape,ndim)
# Out:
# dtype('int32')

# %%
arr.shape
# Out:
# (7,)

# %%
arr.ndim
# Out:
# 1

# %%
arr=np.array((1,2,3))                     #py tuple as numpy array

# %%
arr
# Out:
# array([1, 2, 3])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr[-1]
# Out:
# 3

# %%
dc={1:"hello",2:"TMKOC"}
arr=np.array(dc)                                    #Not recommended as here data is heterogenouus numpy stresses on having homogeneous data so that execution is fast

# %%
arr
# Out:
# array({1: 'hello', 2: 'TMKOC'}, dtype=object)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# ()

# %%
arr.ndim
# Out:
# 0

# %%
arr.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Numpy is useful with numercial homogeneous data as it increases the speed of execution with vectorization which contarsts with the behaviour of normal python lists
