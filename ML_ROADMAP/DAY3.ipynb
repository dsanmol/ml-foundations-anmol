# %%
import numpy as np

# %%
#BroadCasting

# %%
a=[2,2,2]
b=[1,2,3]
c=[]
for i in range(len(b)):
    c.append(a[i]*b[i])

# %%
c
# Out:
# [2, 4, 6]

# %%
#Here we need to have equal sized arrays so that we can do a scalar multiplicaton like 2*b

# %%
b=np.array(b)

# %%
b*2         #Here because of broadcasting we can do this internally is does [2,2,2] * [1,2,3]
# Out:
# array([2, 4, 6])

# %%
a=[1,2,3,4]
b=[1,2]
a=np.array(a)
b=np.array(b)
#print(a+b)                      #Here we can not do broadcasting as the shapes of array differ

# %%
b=np.array(1)
print(a+b)               #Here This is possible a b is of single dimension(1)
# Out:
# [2 3 4 5]

# %%
b
# Out:
# array(1)

# %%
print(b)
# Out:
# 1

# %%
b=[1,2,3,4]
print(a+b)       #here also it is possible as the dimensions are equal here
# Out:
# [2 4 6 8]

# %%
a=np.array([[1],[2]])

# %%
print(a)
# Out:
# [[1]
#  [2]]

# %%
a.shape
# Out:
# (2, 1)

# %%
a.ndim
# Out:
# 2

# %%
b=np.array([[1,2,1],[2,3,1],[3,4,1]])

# %%
b
# Out:
# array([[1, 2, 1],
#        [2, 3, 1],
#        [3, 4, 1]])

# %%
#a+b

# %%
b+a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 b+a
#
# ValueError: operands could not be broadcast together with shapes (3,3) (2,1)

# %%
b.shape
# Out:
# (3, 3)

# %%
a=np.array([[1],[2],[3]])

# %%
a.shape
# Out:
# (3, 1)

# %%
b=np.array([1,2,3,4])

# %%
a+b
# Out:
# array([[2, 3, 4, 5],
#        [3, 4, 5, 6],
#        [4, 5, 6, 7]])

# %%
b+a
# Out:
# array([[2, 3, 4, 5],
#        [3, 4, 5, 6],
#        [4, 5, 6, 7]])
