# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette("Set2")

# %%
data=pd.read_csv("E-commerce Customer Behavior - Sheet1.csv")

# %% [markdown]
# ## Doing a basic level eda to understand patterns and make initial assumptions

# %%
data.head()
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
data.shape
# Out:
# (350, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          2
# dtype: int64

# %%
## Only 2 values of satisfaction level attribute are null so will remove these 2 values

# %%
data["Satisfaction Level"].dropna(inplace=True)         #Returns a pandas series changes applied to series not original dataframe

# %%
data.shape
# Out:
# (350, 11)

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          2
# dtype: int64

# %%
data.dropna(subset=["Satisfaction Level"],inplace=True)       #Correctly deletes data where staisfaction level is null

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 348 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               348 non-null    int64
#  1   Gender                    348 non-null    object
#  2   Age                       348 non-null    int64
#  3   City                      348 non-null    object
#  4   Membership Type           348 non-null    object
#  5   Total Spend               348 non-null    float64
#  6   Items Purchased           348 non-null    int64
#  7   Average Rating            348 non-null    float64
#  8   Discount Applied          348 non-null    bool
#  9   Days Since Last Purchase  348 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 30.2+ KB

# %%
data.shape
# Out:
# (348, 11)

# %%
#Lets look into numerical aspect of the customer data first

# %%
data.describe()
# Out:
#        Customer ID         Age  Total Spend  Items Purchased  Average Rating  \
# count   348.000000  348.000000   348.000000       348.000000      348.000000
# mean    275.887931   33.577586   847.793103        12.632184        4.023563
# std     101.304611    4.878024   361.692375         4.146079        0.579145
# min     101.000000   26.000000   410.800000         7.000000        3.000000
# 25%     188.750000   30.000000   505.750000         9.000000        3.500000
# 50%     276.500000   32.000000   780.200000        12.000000        4.100000
# 75%     363.250000   37.000000  1160.600000        15.000000        4.500000
# max     450.000000   43.000000  1520.100000        21.000000        4.900000
#
#        Days Since Last Purchase
# count                348.000000
# mean                  26.614943
# std                   13.474750
# min                    9.000000
# 25%                   15.000000
# 50%                   23.000000
# 75%                   38.000000
# ...

# %%
#Doing a univariate analysis to understand and make assumptions in a concrete manner

# %%
sns.countplot(data,x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data,x="Membership Type",palette="Set2")
# Out:
# C:\Users\riddh\AppData\Local\Temp\ipykernel_22492\2157082599.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data,x="Membership Type",palette="Set2")
# <Axes: xlabel='Membership Type', ylabel='count'>

# %%
#So here equal number of people in all the types of memberships

# %%
sns.countplot(data,x="Discount Applied")
# Out:
# <Axes: xlabel='Discount Applied', ylabel='count'>

# %%
sns.countplot(data,x="Satisfaction Level")
# Out:
# <Axes: xlabel='Satisfaction Level', ylabel='count'>

# %%
sns.histplot(data,x="Age",bins=6)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data,x="Total Spend",bins=5)
# Out:
# <Axes: xlabel='Total Spend', ylabel='Count'>

# %%
sns.histplot(data,x="Average Rating",bins=5)
# Out:
# <Axes: xlabel='Average Rating', ylabel='Count'>

# %%
sns.histplot(data,x="Items Purchased",bins=5)
# Out:
# <Axes: xlabel='Items Purchased', ylabel='Count'>

# %%
sns.histplot(data,x="Days Since Last Purchase",bins=5)
# Out:
# <Axes: xlabel='Days Since Last Purchase', ylabel='Count'>

# %%
#Bivariate Analysis

# %% [markdown]
# ## 1 Assuming that a higher level membership offers discounts

# %%
plt.figure(figsize=(6,6))
sns.countplot(data,x="Membership Type",hue="Discount Applied")
# Out:
# <Axes: xlabel='Membership Type', ylabel='count'>

# %% [markdown]
# ## 28/02/2026

# %%
## Here our assumption is proven wrong with this plot as here it is clearly visible that the possibility of getting a discount is equal

# %% [markdown]
# ## 2. The second assumption we assume is that the if a customer spends less then it is because of not getting discount

# %%
sns.histplot(data,x="Total Spend",bins=5,hue="Discount Applied")             #this does nothing to our assumption
# Out:
# <Axes: xlabel='Total Spend', ylabel='Count'>

# %%
sns.boxplot(data=data, x="Discount Applied", y="Total Spend", palette=["green","orange"])
# Out:
# C:\Users\riddh\AppData\Local\Temp\ipykernel_22492\2603047951.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x="Discount Applied", y="Total Spend", palette=["green","orange"])
# <Axes: xlabel='Discount Applied', ylabel='Total Spend'>

# %%
# This again proves my assumption wrong that people spend more when offered a discount but rather they spend more when they dont gtet a discount

# %%
## Now lets see the rating of products which customers bought in days since last purchase

# %%
sns.scatterplot(data,x="Days Since Last Purchase",y="Average Rating",hue="Discount Applied")
# Out:
# <Axes: xlabel='Days Since Last Purchase', ylabel='Average Rating'>

# %%
sns.scatterplot(data,x="Days Since Last Purchase",y="Average Rating",hue="Membership Type")
# Out:
# <Axes: xlabel='Days Since Last Purchase', ylabel='Average Rating'>

# %%
sns.scatterplot(data,x="Days Since Last Purchase",y="Average Rating",hue="Satisfaction Level")
# Out:
# <Axes: xlabel='Days Since Last Purchase', ylabel='Average Rating'>

# %%
sns.countplot(data,x="Membership Type",hue="Satisfaction Level")
# Out:
# <Axes: xlabel='Membership Type', ylabel='count'>

# %%
sns.boxplot(data,x="Membership Type",y="Total Spend")
# Out:
# <Axes: xlabel='Membership Type', ylabel='Total Spend'>
